# %%
from __future__ import print_function

import tensorflow as tf
import os

# Dataset Parameters - CHANGE HERE
MODE = 'folder' # or 'file', if you choose a plain text file (see above).
DATASET_PATH = 'DataSet' # the dataset file or root folder path.

# Image Parameters
N_CLASSES = 6 # CHANGE HERE, total number of classes
IMG_HEIGHT = 64 # CHANGE HERE, the image height to be resized to
IMG_WIDTH = 64 # CHANGE HERE, the image width to be resized to
CHANNELS = 3 # The 3 color channels, change to 1 if grayscale

# %%
# Reading the dataset
# 2 modes: 'file' or 'folder'
def read_images(dataset_path, mode, batch_size):
    imagepaths, labels = list(), list()
    if mode == 'file':
        # Read dataset file
        data = open(dataset_path, 'r').read().splitlines()
        for d in data:
            imagepaths.append(d.split(' ')[0])
            labels.append(int(d.split(' ')[1]))
    elif mode == 'folder':
        # An ID will be affected to each sub-folders by alphabetical order
        label = 0
        # List the directory
        try:  # Python 2
            classes = sorted(os.walk(dataset_path).next()[1])
        except Exception:  # Python 3
            classes = sorted(os.walk(dataset_path).__next__()[1])
        # List each sub-directory (the classes)
        for c in classes:
            c_dir = os.path.join(dataset_path, c)
            try:  # Python 2
                walk = os.walk(c_dir).next()
            except Exception:  # Python 3
                walk = os.walk(c_dir).__next__()
            # Add each image to the training set
            for sample in walk[2]:
                # Only keeps jpeg images
                if sample.endswith('.jpg') or sample.endswith('.jpeg'):
                    imagepaths.append(os.path.join(c_dir, sample))
                    labels.append(label)
            label += 1
    else:
        raise Exception("Unknown mode.")

    # Convert to Tensor
    imagepaths = tf.convert_to_tensor(imagepaths, dtype=tf.string)
    labels = tf.convert_to_tensor(labels, dtype=tf.int32)
    # Build a TF Queue, shuffle data
    image, label = tf.train.slice_input_producer([imagepaths, labels],
                                                 shuffle=True)

    # Read images from disk
    image = tf.read_file(image)
    image = tf.image.decode_jpeg(image, channels=CHANNELS)

    # Resize images to a common size
    image = tf.image.resize_images(image, [IMG_HEIGHT, IMG_WIDTH])

    # Normalize
    image = image * 1.0/127.5 - 1.0

    # Create batches
    X, Y = tf.train.batch([image, label], batch_size=batch_size,
                          capacity=batch_size * 8,
                          num_threads=4)

    return X, Y

# %%
# -----------------------------------------------
# THIS IS A CLASSIC CNN (see examples, section 3)
# -----------------------------------------------
# Note that a few elements have changed (usage of queues).

# Parameters
learning_rate = 0.005
num_steps = 10000
batch_size = 128
display_step = 100

# Network Parameters
dropout = 0.75 # Dropout, probability to keep units

# Build the data input
X, Y = read_images(DATASET_PATH, MODE, batch_size)

# %%
# Create model
def conv_net(x, n_classes, dropout, reuse, is_training):
    # Define a scope for reusing the variables
    with tf.variable_scope('ConvNet', reuse=reuse):

        # Convolution Layer with 32 filters and a kernel size of 5
        conv1 = tf.layers.conv2d(x, 32, 5, activation=tf.nn.relu)
        # Max Pooling (down-sampling) with strides of 2 and kernel size of 2
        conv1 = tf.layers.max_pooling2d(conv1, 2, 2)

        # Convolution Layer with 32 filters and a kernel size of 5
        conv2 = tf.layers.conv2d(conv1, 64, 3, activation=tf.nn.relu)
        # Max Pooling (down-sampling) with strides of 2 and kernel size of 2
        conv2 = tf.layers.max_pooling2d(conv2, 2, 2)

        # Flatten the data to a 1-D vector for the fully connected layer
        fc1 = tf.contrib.layers.flatten(conv2)

        # Fully connected layer (in contrib folder for now)
        fc1 = tf.layers.dense(fc1, 1024)
        # Apply Dropout (if is_training is False, dropout is not applied)
        fc1 = tf.layers.dropout(fc1, rate=dropout, training=is_training)

        # Output layer, class prediction
        out = tf.layers.dense(fc1, n_classes)
        # Because 'softmax_cross_entropy_with_logits' already apply softmax,
        # we only apply softmax to testing network
        out = tf.nn.softmax(out) if not is_training else out

    return out

# %%
# Because Dropout have different behavior at training and prediction time, we
# need to create 2 distinct computation graphs that share the same weights.

# Create a graph for training
logits_train = conv_net(X, N_CLASSES, dropout, reuse=False, is_training=True)
# Create another graph for testing that reuse the same weights
logits_test = conv_net(X, N_CLASSES, dropout, reuse=True, is_training=False)

# Define loss and optimizer (with train logits, for dropout to take effect)
loss_op = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(
    logits=logits_train, labels=Y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
train_op = optimizer.minimize(loss_op)

# Evaluate model (with test logits, for dropout to be disabled)
correct_pred = tf.equal(tf.argmax(logits_test, 1), tf.cast(Y, tf.int64))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initialize the variables (i.e. assign their default value)
init = tf.global_variables_initializer()

# Saver object
saver = tf.train.Saver()

# Start training
with tf.Session() as sess:

    # Run the initializer
    sess.run(init)

    # Start the data queue
    tf.train.start_queue_runners()

    # Training cycle
    for step in range(1, num_steps+1):

        if step % display_step == 0:
            # Run optimization and calculate batch loss and accuracy
            _, loss, acc = sess.run([train_op, loss_op, accuracy])
            print("Step " + str(step) + ", Minibatch Loss= " + \
                  "{:.4f}".format(loss) + ", Training Accuracy= " + \
                  "{:.3f}".format(acc))
        else:
            # Only run the optimization op (backprop)
            sess.run(train_op)

    print("Optimization Finished!")

    # Save your model
    saver.save(sess, 'my_tf_model')
# Out:
# Step 100, Minibatch Loss= 0.0062, Training Accuracy= 1.000
# Step 200, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Step 300, Minibatch Loss= 0.0006, Training Accuracy= 1.000
# Step 400, Minibatch Loss= 0.0057, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Step 600, Minibatch Loss= 0.0544, Training Accuracy= 1.000
# Step 700, Minibatch Loss= 0.0177, Training Accuracy= 1.000
# Step 800, Minibatch Loss= 0.0011, Training Accuracy= 1.000
# Step 900, Minibatch Loss= 0.0000, Training Accuracy= 1.000
# Step 1000, Minibatch Loss= 0.0000, Training Accuracy= 1.000
# Step 1100, Minibatch Loss= 0.0000, Training Accuracy= 1.000
# Step 1200, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Step 1300, Minibatch Loss= 0.0000, Training Accuracy= 1.000
# Step 1400, Minibatch Loss= 0.0000, Training Accuracy= 1.000
# Step 1500, Minibatch Loss= 0.0000, Training Accuracy= 1.000
# Step 1600, Minibatch Loss= 0.0000, Training Accuracy= 1.000
# Step 1700, Minibatch Loss= 0.0000, Training Accuracy= 1.000
# Step 1800, Minibatch Loss= 0.0000, Training Accuracy= 1.000
# Step 1900, Minibatch Loss= 0.0000, Training Accuracy= 1.000
# Step 2000, Minibatch Loss= 0.0000, Training Accuracy= 1.000
# Step 2100, Minibatch Loss= 0.0000, Training Accuracy= 1.000
# Step 2200, Minibatch Loss= 0.0000, Training Accuracy= 1.000
# Step 2300, Minibatch Loss= 0.0000, Training Accuracy= 1.000
# Step 2400, Minibatch Loss= 0.0000, Training Accuracy= 1.000
# Step 2500, Minibatch Loss= 0.0000, Training Accuracy= 1.000
# Step 2600, Minibatch Loss= 0.0000, Training Accuracy= 1.000
# Step 2700, Minibatch Loss= 0.0848, Training Accuracy= 0.984
# Step 2800, Minibatch Loss= 0.0688, Training Accuracy= 0.984
# Step 2900, Minibatch Loss= 0.0011, Training Accuracy= 1.000
# Step 3000, Minibatch Loss= 0.0000, Training Accuracy= 1.000
# Step 3100, Minibatch Loss= 0.0000, Training Accuracy= 1.000
# Step 3200, Minibatch Loss= 0.0000, Training Accuracy= 1.000
# Step 3300, Minibatch Loss= 0.0000, Training Accuracy= 1.000
# Step 3400, Minibatch Loss= 0.0000, Training Accuracy= 1.000
# Step 3500, Minibatch Loss= 0.0000, Training Accuracy= 1.000
# Step 3600, Minibatch Loss= 0.0000, Training Accuracy= 1.000
# Step 3700, Minibatch Loss= 0.0000, Training Accuracy= 1.000
# Step 3800, Minibatch Loss= 0.0000, Training Accuracy= 1.000
# Step 3900, Minibatch Loss= 0.6390, Training Accuracy= 0.953
# Step 4000, Minibatch Loss= 0.0441, Training Accuracy= 0.969
# Step 4100, Minibatch Loss= 0.0262, Training Accuracy= 0.984
# Step 4200, Minibatch Loss= 0.0000, Training Accuracy= 1.000
# Step 4300, Minibatch Loss= 0.0649, Training Accuracy= 0.984
# Step 4400, Minibatch Loss= 0.0255, Training Accuracy= 0.984
# Step 4500, Minibatch Loss= 0.0527, Training Accuracy= 0.984
# Step 4600, Minibatch Loss= 0.0415, Training Accuracy= 0.984
# Step 4700, Minibatch Loss= 0.0434, Training Accuracy= 0.984
# Step 4800, Minibatch Loss= 0.0384, Training Accuracy= 0.984
# Step 4900, Minibatch Loss= 0.0755, Training Accuracy= 0.969
# Step 5000, Minibatch Loss= 0.0697, Training Accuracy= 0.969
# Step 5100, Minibatch Loss= 0.0756, Training Accuracy= 0.969
# Step 5200, Minibatch Loss= 0.0805, Training Accuracy= 0.969
# Step 5300, Minibatch Loss= 0.0754, Training Accuracy= 0.969
# Step 5400, Minibatch Loss= 0.0640, Training Accuracy= 0.969
# Step 5500, Minibatch Loss= 0.0690, Training Accuracy= 0.969
# Step 5600, Minibatch Loss= 0.0631, Training Accuracy= 0.969
# Step 5700, Minibatch Loss= 0.0719, Training Accuracy= 0.969
# Step 5800, Minibatch Loss= 0.0636, Training Accuracy= 0.969
# Step 5900, Minibatch Loss= 0.0463, Training Accuracy= 0.969
# Step 6000, Minibatch Loss= 0.0330, Training Accuracy= 0.984
# Step 6100, Minibatch Loss= 0.0363, Training Accuracy= 0.984
# Step 6200, Minibatch Loss= 0.0485, Training Accuracy= 0.984
# Step 6300, Minibatch Loss= 0.0347, Training Accuracy= 0.984
# Step 6400, Minibatch Loss= 0.0019, Training Accuracy= 1.000
# Step 6500, Minibatch Loss= 0.8360, Training Accuracy= 0.883
# Step 6600, Minibatch Loss= 0.0237, Training Accuracy= 0.984
# Step 6700, Minibatch Loss= 0.0331, Training Accuracy= 0.984
# Step 6800, Minibatch Loss= 0.0282, Training Accuracy= 0.984
# Step 6900, Minibatch Loss= 0.0298, Training Accuracy= 0.984
# Step 7000, Minibatch Loss= 0.0330, Training Accuracy= 0.984
# Step 7100, Minibatch Loss= 0.0230, Training Accuracy= 0.984
# Step 7200, Minibatch Loss= 0.0389, Training Accuracy= 0.969
# Step 7300, Minibatch Loss= 0.0407, Training Accuracy= 0.984
# Step 7400, Minibatch Loss= 0.0329, Training Accuracy= 0.984
# Step 7500, Minibatch Loss= 0.0215, Training Accuracy= 0.984
# Step 7600, Minibatch Loss= 0.0137, Training Accuracy= 0.984
# Step 7700, Minibatch Loss= 0.0190, Training Accuracy= 0.984
# Step 7800, Minibatch Loss= 0.1145, Training Accuracy= 0.953
# Step 7900, Minibatch Loss= 0.0137, Training Accuracy= 0.992
# Step 8000, Minibatch Loss= 0.0473, Training Accuracy= 0.984
# Step 8100, Minibatch Loss= 0.0327, Training Accuracy= 0.984
# Step 8200, Minibatch Loss= 0.0398, Training Accuracy= 0.984
# Step 8300, Minibatch Loss= 0.0250, Training Accuracy= 0.984
# Step 8400, Minibatch Loss= 0.0231, Training Accuracy= 0.984
# Step 8500, Minibatch Loss= 0.0342, Training Accuracy= 0.984
# Step 8600, Minibatch Loss= 0.0357, Training Accuracy= 0.984
# Step 8700, Minibatch Loss= 0.0347, Training Accuracy= 0.984
# Step 8800, Minibatch Loss= 0.0406, Training Accuracy= 0.984
# Step 8900, Minibatch Loss= 0.0445, Training Accuracy= 0.984
# Step 9000, Minibatch Loss= 0.0239, Training Accuracy= 0.984
# Step 9100, Minibatch Loss= 0.0201, Training Accuracy= 0.984
# Step 9200, Minibatch Loss= 0.0175, Training Accuracy= 0.984
# Step 9300, Minibatch Loss= 0.0211, Training Accuracy= 0.984
# Step 9400, Minibatch Loss= 0.0264, Training Accuracy= 0.984
# Step 9500, Minibatch Loss= 0.0148, Training Accuracy= 0.984
# Step 9600, Minibatch Loss= 0.0274, Training Accuracy= 0.984
# Step 9700, Minibatch Loss= 0.0332, Training Accuracy= 0.984
# Step 9800, Minibatch Loss= 0.0613, Training Accuracy= 0.984
# Step 9900, Minibatch Loss= 0.0443, Training Accuracy= 0.984
# Step 10000, Minibatch Loss= 0.0489, Training Accuracy= 0.984
# Optimization Finished!
# ERROR:tensorflow:Exception in QueueRunner: Enqueue operation was cancelled
# 	 [[Node: input_producer/input_producer/input_producer_EnqueueMany = QueueEnqueueManyV2[Tcomponents=[DT_INT32], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/cpu:0"](input_producer/input_producer, input_producer/input_producer/RandomShuffle)]]
# ERROR:tensorflow:Exception in QueueRunner: Enqueue operation was cancelled
# 	 [[Node: batch/fifo_queue_enqueue = QueueEnqueueV2[Tcomponents=[DT_FLOAT, DT_INT32], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/cpu:0"](batch/fifo_queue, sub/_9, input_producer/Gather_1)]]
# ERROR:tensorflow:Exception in QueueRunner: Enqueue operation was cancelled
# 	 [[Node: batch/fifo_queue_enqueue = QueueEnqueueV2[Tcomponents=[DT_FLOAT, DT_INT32], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/cpu:0"](batch/fifo_queue, sub/_9, input_producer/Gather_1)]]
# Exception in thread Thread-4:
# Traceback (most recent call last):
#   File "/usr/lib64/python3.4/threading.py", line 920, in _bootstrap_inner
#     self.run()
#   File "/usr/lib64/python3.4/threading.py", line 868, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.4/dist-packages/tensorflow/python/training/queue_runner_impl.py", line 238, in _run
#     enqueue_callable()
#   File "/usr/lib/python3.4/dist-packages/tensorflow/python/client/session.py", line 1235, in _single_operation_run
#     target_list_as_strings, status, None)
#   File "/usr/lib64/python3.4/contextlib.py", line 66, in __exit__
#     next(self.gen)
#   File "/usr/lib/python3.4/dist-packages/tensorflow/python/framework/errors_impl.py", line 466, in raise_exception_on_not_ok_status
#     pywrap_tensorflow.TF_GetCode(status))
# tensorflow.python.framework.errors_impl.CancelledError: Enqueue operation was cancelled
# 	 [[Node: input_producer/input_producer/input_producer_EnqueueMany = QueueEnqueueManyV2[Tcomponents=[DT_INT32], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/cpu:0"](input_producer/input_producer, input_producer/input_producer/RandomShuffle)]]
#
# Exception in thread Thread-8:
# Traceback (most recent call last):
#   File "/usr/lib64/python3.4/threading.py", line 920, in _bootstrap_inner
#     self.run()
#   File "/usr/lib64/python3.4/threading.py", line 868, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.4/dist-packages/tensorflow/python/training/queue_runner_impl.py", line 238, in _run
#     enqueue_callable()
#   File "/usr/lib/python3.4/dist-packages/tensorflow/python/client/session.py", line 1235, in _single_operation_run
#     target_list_as_strings, status, None)
#   File "/usr/lib64/python3.4/contextlib.py", line 66, in __exit__
#     next(self.gen)
#   File "/usr/lib/python3.4/dist-packages/tensorflow/python/framework/errors_impl.py", line 466, in raise_exception_on_not_ok_status
#     pywrap_tensorflow.TF_GetCode(status))
# tensorflow.python.framework.errors_impl.CancelledError: Enqueue operation was cancelled
# 	 [[Node: batch/fifo_queue_enqueue = QueueEnqueueV2[Tcomponents=[DT_FLOAT, DT_INT32], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/cpu:0"](batch/fifo_queue, sub/_9, input_producer/Gather_1)]]
# ERROR:tensorflow:Exception in QueueRunner: Enqueue operation was cancelled
# 	 [[Node: batch/fifo_queue_enqueue = QueueEnqueueV2[Tcomponents=[DT_FLOAT, DT_INT32], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/cpu:0"](batch/fifo_queue, sub/_9, input_producer/Gather_1)]]
# ERROR:tensorflow:Exception in QueueRunner: Enqueue operation was cancelled
# 	 [[Node: batch/fifo_queue_enqueue = QueueEnqueueV2[Tcomponents=[DT_FLOAT, DT_INT32], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/cpu:0"](batch/fifo_queue, sub/_9, input_producer/Gather_1)]]
# Exception in thread Thread-6:
# Traceback (most recent call last):
#   File "/usr/lib64/python3.4/threading.py", line 920, in _bootstrap_inner
#     self.run()
#   File "/usr/lib64/python3.4/threading.py", line 868, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.4/dist-packages/tensorflow/python/training/queue_runner_impl.py", line 238, in _run
#     enqueue_callable()
#   File "/usr/lib/python3.4/dist-packages/tensorflow/python/client/session.py", line 1235, in _single_operation_run
#     target_list_as_strings, status, None)
#   File "/usr/lib64/python3.4/contextlib.py", line 66, in __exit__
#     next(self.gen)
#   File "/usr/lib/python3.4/dist-packages/tensorflow/python/framework/errors_impl.py", line 466, in raise_exception_on_not_ok_status
#     pywrap_tensorflow.TF_GetCode(status))
# tensorflow.python.framework.errors_impl.CancelledError: Enqueue operation was cancelled
# 	 [[Node: batch/fifo_queue_enqueue = QueueEnqueueV2[Tcomponents=[DT_FLOAT, DT_INT32], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/cpu:0"](batch/fifo_queue, sub/_9, input_producer/Gather_1)]]
#
# Exception in thread Thread-5:
# Traceback (most recent call last):
#   File "/usr/lib64/python3.4/threading.py", line 920, in _bootstrap_inner
#     self.run()
#   File "/usr/lib64/python3.4/threading.py", line 868, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.4/dist-packages/tensorflow/python/training/queue_runner_impl.py", line 238, in _run
#     enqueue_callable()
#   File "/usr/lib/python3.4/dist-packages/tensorflow/python/client/session.py", line 1235, in _single_operation_run
#     target_list_as_strings, status, None)
#   File "/usr/lib64/python3.4/contextlib.py", line 66, in __exit__
#     next(self.gen)
#   File "/usr/lib/python3.4/dist-packages/tensorflow/python/framework/errors_impl.py", line 466, in raise_exception_on_not_ok_status
#     pywrap_tensorflow.TF_GetCode(status))
# tensorflow.python.framework.errors_impl.CancelledError: Enqueue operation was cancelled
# 	 [[Node: batch/fifo_queue_enqueue = QueueEnqueueV2[Tcomponents=[DT_FLOAT, DT_INT32], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/cpu:0"](batch/fifo_queue, sub/_9, input_producer/Gather_1)]]
#
# Exception in thread Thread-7:
# Traceback (most recent call last):
#   File "/usr/lib64/python3.4/threading.py", line 920, in _bootstrap_inner
#     self.run()
#   File "/usr/lib64/python3.4/threading.py", line 868, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.4/dist-packages/tensorflow/python/training/queue_runner_impl.py", line 238, in _run
#     enqueue_callable()
#   File "/usr/lib/python3.4/dist-packages/tensorflow/python/client/session.py", line 1235, in _single_operation_run
#     target_list_as_strings, status, None)
#   File "/usr/lib64/python3.4/contextlib.py", line 66, in __exit__
#     next(self.gen)
#   File "/usr/lib/python3.4/dist-packages/tensorflow/python/framework/errors_impl.py", line 466, in raise_exception_on_not_ok_status
#     pywrap_tensorflow.TF_GetCode(status))
# tensorflow.python.framework.errors_impl.CancelledError: Enqueue operation was cancelled
# 	 [[Node: batch/fifo_queue_enqueue = QueueEnqueueV2[Tcomponents=[DT_FLOAT, DT_INT32], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/cpu:0"](batch/fifo_queue, sub/_9, input_producer/Gather_1)]]
